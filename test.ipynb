# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL of the website
url = "https://www.khmer24.com/en/c-cars-for-sale?keyword=&ad_field=lexus&ad_type=other"

# Send a request to the website
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36'
}
response = requests.get(url, headers=headers)
html_content = response.content

# Parse the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find all car listings
car_listings = soup.find_all('article', class_='width_list_grid_dt')
print(f"Found {len(car_listings)} car listings.")  # Debugging

# Initialize a list to store the data
data = []

# Loop through each car listing and extract the required information
for listing in car_listings:
    try:
        # Extract car ID from the href link
        link_tag = listing.find('a', class_='position_relative d_block')
        car_id = link_tag.get('href', '').split('-')[-1] if link_tag else 'N/A'
        
        # Extract the title
        title = listing.find('p', class_='truncate gr-p-title')
        title = title.text.strip() if title else 'N/A'

        # Extract details like location and time
        details = listing.find('p', class_='truncate gr-p-date-loc')
        details_text = details.text.strip() if details else 'N/A'

        # Split details to separate location and other info
        location = details_text.split('•')[-1].strip() if '•' in details_text else 'N/A'

        # Extract the image URL if available
        image_tag = listing.find('img', class_='lazy height_media ing_post_listing img_product bg_reload_img')
        image_url = image_tag.get('src', 'N/A') if image_tag else 'N/A'

        # Append extracted data to the list
        data.append([car_id, title, 'Car', 'Lexus', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', 'N/A', location, 'N/A', image_url])

    except Exception as e:
        print(f"Error processing a listing: {e}")

# Check if data is populated
if not data:
    print("No data extracted. Check your selectors or the website structure.")

# Define the CSV file name
csv_file = 'car_listings_updated.csv'

# Write the data to a CSV file
with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    # Write the header
    writer.writerow([
        'Car_id', 'Title', 'Category', 'Brand', 'Model', 'Year', 'Tax_type', 
        'Condition', 'Body_type', 'Fuel', 'Transmission', 'Color', 'Location', 'Price', 'Image_URL'
    ])
    # Write the data
    writer.writerows(data)

print(f"Data has been saved to {csv_file}")

# %%
import cloudscraper
from bs4 import BeautifulSoup

url = 'https://www.khmer24.com/c-cars-for-sale'
scraper = cloudscraper.create_scraper()  # Create a cloudscraper instance
response = scraper.get(url)  # Use the scraper instance to fetch the web page
html_content = response.content
soup = BeautifulSoup(html_content, 'html.parser')

car_listings = soup.find_all('div', class_='my_card p-h')
car_url = []
for i, car in enumerate(car_listings):
    for img in car.find_all('a'):
        uri = img.get('href')
        url = "https://www.khmer24.com"+uri

        print(f"Link: {url}")
        car_url.append(url)
    pass
print(len(car_url))
# Out:
# Link: https://www.khmer24.com/high-lander-v6-%E1%9E%94%E1%9F%89%E1%9E%BB%E1%9E%84-2-%E1%9E%A0%E1%9F%92%E1%9E%9C%E1%9E%BC%E1%9E%9B%E1%9E%A2%E1%9E%BB%E1%9E%94%E1%9E%9F%E1%9E%B7%E1%9E%93-full-option-adid-11621171
# Link: https://www.khmer24.com/very-new-bmw-m4-2015-convertible-full-option-for-sale-on-special-price-adid-11658879
# Link: https://www.khmer24.com/2012-daewoo-damas-for-sale-adid-11700233
# Link: https://www.khmer24.com/isuzu-refrigerator-truck--year-2020-adid-11706837
# Link: https://www.khmer24.com/2003%E5%B9%B4%E9%99%86%E5%B7%A1%EF%BC%8C%E8%BD%A6%E5%86%B5%E6%AD%A3%E5%B8%B8%EF%BC%8C%E5%BE%88%E6%96%B0-adid-11729956
# Link: https://www.khmer24.com/lexus-ct200h-2013-f-sport-adid-11722766
# Link: https://www.khmer24.com/aphard-2016-up-2022-adid-11690148
# Link: https://www.khmer24.com/starex-2008-adid-11740256
# Link: https://www.khmer24.com/%E1%9E%A1%E1%9E%B6%E1%9E%93010-option-2-%E1%9E%9B%E1%9E%80%E1%9F%8B16600--adid-11676438
# Link: https://www.khmer24.com/rang-rover-voque-black-2014-v6--3-0l-%E1%9E%9F%E1%9E%B6%E1%9F%86%E1%9E%84-gesoline---tax-paper-%E1%9E%80%E1%9F%92%E1%9E%93%E1%9E%BB%E1%9E%84%E1%9E%81%E1%9F%92%E1%9E%98%E1%9F%85-%E1%9E%A1%E1%9E%B6%E1%9E%93%E1%9E%98%E1%9E%BC%E1%9E%9B%E1%9E%9F%E1%9F%92%E1%9E%A2%E1%9E%B6%E1%9E%8F%E1%9E%94%E1%9E%84%E1%9F%97--49999--adid-11341947
# Link: https://www.khmer24.com/land-cruiser-v6-adid-11640158
# Link: https://www.khmer24.com/%E2%9A%A1%EF%B8%8Ftoyota-pruis-2012%E2%9A%A1%EF%B8%8F-adid-11730855
# Link: https://www.khmer24.com/lexus-hs250h-2010full-advanced-technology-adid-11292635
# Link: https://www.khmer24.com/%E1%9E%9A%E1%9E%90%E1%9E%99%E1%9E%93%E1%9F%92%E1%9E%8F%E1%9E%9F%E1%9E%84%E1%9F%92%E1%9E%82%E1%9F%92%E1%9E%9A%E1%9F%84%E1%9F%87-adid-11735920
# Link: https://www.khmer24.com/tacoma-%E1%9E%86%E1%9F%92%E1%9E%93%E1%9E%B6%E1%9F%8603-abs-v6-%E1%9E%94%E1%9F%89%E1%9E%BB%E1%9E%84%E1%9E%97%E1%9F%92%E1%9E%9B%E1%9E%BE%E1%9E%84-%E1%9E%A1%E1%9E%B6%E1%9E%93%E1%9E%9F%E1%9F%92%E1%9E%A2%E1%9E%B6%E1%9E%8F-%E1%9E%9B%E1%9F%81%E1%9E%84%E1%9E%A0%E1%9E%BE%E1%9E%99-adid-11622730
# Link: https://www.khmer24.com/jaguar-f-type-s-2015-adid-11722638
# Link: https://www.khmer24.com/%E1%9E%A1%E1%9E%B6%E1%9E%93%E1%9E%9B%E1%9E%80%E1%9F%8B-adid-11733197
# Link: https://www.khmer24.com/toyota-alphard-2015-exclusive-lounge-hybrid-adid-11675610
# Link: https://www.khmer24.com/toyota-adid-11673268
# Link: https://www.khmer24.com/toyota-raize-adid-11531033
# Link: https://www.khmer24.com/toyota-alpha-2019-v6-full-option-adid-11640409
# Link: https://www.khmer24.com/toyota-alphard-2010-halfull-%E1%9E%9F%E1%9E%B6%E1%9E%84%E1%9E%94%E1%9E%B6%E1%9E%93%E1%9E%8F%E1%9E%98%E1%9F%92%E1%9E%9B%E1%9F%83%E1%9E%9B%E1%9F%92%E1%9E%A2%F0%9F%8C%B8%E2%9D%A3%EF%B8%8F-adid-11740684
# Link: https://www.khmer24.com/volkswagen-%E1%9E%98%E1%9F%92%E1%9E%85%E1%9E%B6%E1%9E%9F%E1%9F%8B%E1%9E%8A%E1%9E%BE%E1%9E%98--%E1%9E%85%E1%9E%9A%E1%9E%85%E1%9E%B6%E1%9E%94%E1%9E%B6%E1%9E%93%E1%9E%91%E1%9F%80%E1%9E%8F-adid-11717692
# Link: https://www.khmer24.com/prius-v-option-5-advanced-auto-parking-012-adid-11428368
# Link: https://www.khmer24.com/bentley-2015-%E1%9E%98%E1%9F%92%E1%9E%85%E1%9E%B6%E1%9E%9F%E1%9F%8B%E1%9E%95%E1%9F%92%E1%9E%91%E1%9E%B6%E1%9E%9B%E1%9F%8B-%E1%9E%85%E1%9E%BB%E1%9F%8710000--adid-11730801
# Link: https://www.khmer24.com/%E1%9E%A1%E1%9E%B6%E1%9E%93%E1%9E%9B%E1%9E%80%E1%9F%8B%E2%80%8B-adid-11732670
# Link: https://www.khmer24.com/prius-06-full-%E1%9E%80%E1%9F%92%E1%9E%93%E1%9E%BB%E1%9E%84%E1%9E%9B%E1%9E%BF%E1%9E%84%E1%9E%A1%E1%9E%B6%E1%9E%93%E1%9E%9F%E1%9F%92%E1%9E%A2%E1%9E%B6%E1%9E%8F-adid-11727246
# Link: https://www.khmer24.com/f-150-raptor-adid-11738966
# Link: https://www.khmer24.com/toyota-alphard2012-full-option-%E1%9E%8F%E1%9E%98%E1%9F%92%E1%9E%9B%E1%9F%83%E1%9E%9F%E1%9E%B6%E1%9E%84%E1%9E%87%E1%9E%BC%E1%9E%93%F0%9F%8C%B8%E2%9D%A3%EF%B8%8F-adid-11565118
# Link: https://www.khmer24.com/%E1%9E%A1%E1%9E%B6%E1%9E%93%E1%9E%9B%E1%9E%80%E1%9F%8B-%E1%9E%98%E1%9F%89%E1%9E%BC%E1%9E%8A%E1%9F%82%E1%9E%9B-starex-hvx-%E1%9E%86%E1%9F%92%E1%9E%93%E1%9E%B6%E1%9F%86-2012-adid-11549756
# 30
